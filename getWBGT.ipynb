# %% [markdown]
# this part of code is needed when run from google colab. The code should be copied to
# a local folder

# %%
try : 

	import google.colab
	import os
	
	if not os.path.exists("wbgt") :
		os.system("git clone https://github.com/janmenssen/wbgt.git")
	os.system("cd wbgt")

except :
	pass

# %% [markdown]
# and now run the code

# %%
from python.wbgt import wbgt

myWBGT = wbgt("Gilze-Rijen")

myWBGT.input()
myWBGT.readData()
myWBGT.plot()
myWBGT.list()
# Out:
# 36 files received ...
# 10 (of 36) files processed ...
# 20 (of 36) files processed ...
# 30 (of 36) files processed ...
# 36 (of 36) files processed ...
# Time                     WBGT  HeatIndex
# ----------------------------------------
# 16-07-2026 13:20         26.3     7
# 16-07-2026 13:30         26.0     6
# 16-07-2026 13:40         24.5     6
# 16-07-2026 13:50         23.4     5
# 16-07-2026 14:00         23.1     5
# 16-07-2026 14:10         25.1     6
# 16-07-2026 14:20         26.4     7
# 16-07-2026 14:30         25.5     6
# 16-07-2026 14:40         23.8     5
# 16-07-2026 14:50         26.9     7
# 16-07-2026 15:00         25.0     6
# 16-07-2026 15:10         24.8     6
# 16-07-2026 15:20         24.8     6
# 16-07-2026 15:30         22.7     5
# 16-07-2026 15:40         22.9     5
# 16-07-2026 15:50         22.9     5
# 16-07-2026 16:00         22.9     5
# 16-07-2026 16:10         23.1     5
# 16-07-2026 16:20         22.8     5
# ...
