# %% [markdown]
# **this part of code is needed when run from google colab. The code should be copied to
# a local folder**

# %%
try : 

	import google.colab
	import os
	
	# if python folder doesn't exist, copy the necesaary python files

	if not os.path.exists("python") :

		os.system("mkdir python")
		os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/python/opendata.py -O python/opendata.py")
		os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/wbgt.py -O python/wbgt.py")

		print("necessary files copied ...")
		
except :
	
	print("this is not a Google Colab environment ...")
	pass

# %% [markdown]
# **and now run the code**

# %%
from python.wbgt import wbgt

myWBGT = wbgt("Gilze-Rijen")

myWBGT.input()
myWBGT.readData()
myWBGT.plot()
myWBGT.list()
# Out:
# 35 files received ...
# 10 (of 35) files processed ...
# 20 (of 35) files processed ...
# 30 (of 35) files processed ...
# 35 (of 35) files processed ...
# Time                     WBGT  HeatIndex
# ----------------------------------------
# 17-07-2026 06:20         16.7     2
# 17-07-2026 06:30         16.9     2
# 17-07-2026 06:40         17.3     2
# 17-07-2026 06:50         17.7     2
# 17-07-2026 07:00         17.9     2
# 17-07-2026 07:10         18.2     3
# 17-07-2026 07:20         18.3     3
# 17-07-2026 07:30         18.7     3
# 17-07-2026 07:40         18.6     3
# 17-07-2026 07:50         18.4     3
# 17-07-2026 08:00         18.2     3
# 17-07-2026 08:10         18.2     3
# 17-07-2026 08:20         19.3     3
# 17-07-2026 08:30         19.4     3
# 17-07-2026 08:40         20.3     4
# 17-07-2026 08:50         20.7     4
# 17-07-2026 09:00         19.3     3
# 17-07-2026 09:10         19.6     3
# 17-07-2026 09:20         19.9     3
# 17-07-2026 09:30         20.6     4
# 17-07-2026 09:40         21.1     4
# 17-07-2026 09:50         20.8     4
# 17-07-2026 10:00         19.9     3
# 17-07-2026 10:10         21.3     4
# 17-07-2026 10:20         20.8     4
# 17-07-2026 10:30         20.6     4
# 17-07-2026 10:40         20.9     4
# 17-07-2026 10:50         20.5     4
# 17-07-2026 11:00         21.1     4
# 17-07-2026 11:10         21.7     4
# 17-07-2026 11:20         21.4     4
# 17-07-2026 11:30         20.4     4
# 17-07-2026 11:40         21.8     4
# 17-07-2026 11:50         20.1     4
# 17-07-2026 12:00         21.0     4
