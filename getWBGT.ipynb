# %% [markdown]
# **this part of code is needed when run from google colab. The code should be copied to
# a local folder**

# %%
try : 

	import google.colab
	import os
	
	# if python folder doesn't exist, copy the necesaary python files

	if not os.path.exists("python") :
		os.system("mkdir python")

	os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/python/opendata.py -O python/opendata.py")
	os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/python/openwbgt.py -O python/openwbgt.py")

	print("necessary files copied ...")
		
except :
	
	print("this is not a Google Colab environment ...")
	pass
# Out:
# this is not a Google Colab environment ...

# %% [markdown]
# **and now run the code**

# %%
from python.openwbgt import OpenWBGT

myWBGT = OpenWBGT("Gilze-Rijen")

myWBGT.input()
myWBGT.readData()
myWBGT.plot()
myWBGT.list()
# Out:
# 36 files received ...
# 10 (of 36) files processed ...
# 20 (of 36) files processed ...
# 30 (of 36) files processed ...
# 36 (of 36) files processed ...
# Time                     WBGT  HeatIndex
# ----------------------------------------
# 17-07-2026 09:50         20.8     4
# 17-07-2026 10:00         19.9     3
# 17-07-2026 10:10         21.3     4
# 17-07-2026 10:20         20.8     4
# 17-07-2026 10:30         20.6     4
# 17-07-2026 10:40         20.9     4
# 17-07-2026 10:50         20.5     4
# 17-07-2026 11:00         21.1     4
# 17-07-2026 11:10         21.7     4
# 17-07-2026 11:20         21.4     4
# 17-07-2026 11:30         20.4     4
# 17-07-2026 11:40         21.8     4
# 17-07-2026 11:50         20.1     4
# 17-07-2026 12:00         21.0     4
# 17-07-2026 12:10         21.4     4
# 17-07-2026 12:20         20.0     3
# 17-07-2026 12:30         21.7     4
# 17-07-2026 12:40         21.4     4
# 17-07-2026 12:50         21.2     4
# 17-07-2026 13:00         21.5     4
# 17-07-2026 13:10         21.7     4
# 17-07-2026 13:20         21.7     4
# 17-07-2026 13:30         21.9     4
# 17-07-2026 13:40         23.9     5
# 17-07-2026 13:50         21.4     4
# 17-07-2026 14:00         22.3     5
# 17-07-2026 14:10         23.9     5
# 17-07-2026 14:20         23.9     5
# 17-07-2026 14:30         23.1     5
# 17-07-2026 14:40         22.5     5
# 17-07-2026 14:50         22.7     5
# 17-07-2026 15:00         23.8     5
# 17-07-2026 15:10         22.7     5
# 17-07-2026 15:20         21.8     4
# 17-07-2026 15:30         22.7     5
# 17-07-2026 15:40         23.2     5
