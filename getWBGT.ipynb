# %% [markdown]
# **this part of code is needed when run from google colab. The code should be run once**

# %%
try : 

	import google.colab
	import os
	
	# if python folder doesn't exist, copy the necesaary python files

	if not os.path.exists("python") :
		os.system("mkdir python")

	os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/python/opendata.py -O python/opendata.py")
	os.system("wget https://raw.githubusercontent.com/JanMenssen/2026-wbgt/main/python/openwbgt.py -O python/openwbgt.py")

	print("necessary files copied ...")
		
except :
	
	print("this is not a Google Colab environment ...")
	pass

# %% [markdown]
# **Reload if necessary (files changed)**

# %%
import importlib
import python.openwbgt as openwbgt
import python.opendata as opendata

importlib.reload(openwbgt)
importlib.reload(opendata)
# Out:
# <module 'python.opendata' from '/Users/jan/Library/CloudStorage/OneDrive-Personal/my projects/2026-wbgt/python/opendata.py'>

# %% [markdown]
# **and now run the code**

# %%
from python.openwbgt import OpenWBGT

myWBGT = OpenWBGT("Gilze-Rijen Airport")

myWBGT.input()
myWBGT.readData()
myWBGT.plot()
myWBGT.list()
# Out:
# 36 files received ...
# 10 (of 36) files processed ...
# 20 (of 36) files processed ...
# 30 (of 36) files processed ...
# 36 (of 36) files processed ...
# Time                     WBGT  HeatIndex
# ----------------------------------------
# 28-07-2026 14:30         24.8     6
# 28-07-2026 14:40         25.6     6
# 28-07-2026 14:50         26.6     7
# 28-07-2026 15:00         26.9     7
# 28-07-2026 15:10         25.1     6
# 28-07-2026 15:20         25.0     6
# 28-07-2026 15:30         26.2     7
# 28-07-2026 15:40         26.0     7
# 28-07-2026 15:50         25.6     6
# 28-07-2026 16:00         26.4     7
# 28-07-2026 16:10         24.4     6
# 28-07-2026 16:20         25.4     6
# 28-07-2026 16:30         25.7     6
# 28-07-2026 16:40         25.0     6
# 28-07-2026 16:50         26.1     7
# 28-07-2026 17:00         23.9     5
# 28-07-2026 17:10         24.8     6
# 28-07-2026 17:20         25.1     6
# 28-07-2026 17:30         25.0     6
# ...
